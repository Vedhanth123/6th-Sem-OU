# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import pandas as pd
import matplotlib.pyplot as plt

# %%
titanic = pd.read_csv('train.csv')

titanic.Sex = titanic.Sex.map({'male':0, 'female':1})
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 2                               Heikkinen, Miss. Laina    1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# 4                             Allen, Mr. William Henry    0  35.0      0
# ..                                                 ...  ...   ...    ...
# 886                              Montvila, Rev. Juozas    0  27.0      0
# 887                       Graham, Miss. Margaret Edith    1  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"    1   NaN      1
# 889                              Behr, Mr. Karl Howell    0  26.0      0
# 890                                Dooley, Mr. Patrick    0  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
y = titanic.Survived.copy()
x = titanic.drop(['Survived'],axis=1)

# %%
x.drop(['Cabin','Ticket','Name','PassengerId', 'Embarked'], axis=1, inplace=True)

# %%
x.Age.fillna(x.Age.mean(), inplace=True)
# Out:
# C:\Users\gvedh\AppData\Local\Temp\ipykernel_21824\2460688031.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   x.Age.fillna(x.Age.mean(), inplace=True)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state = 7)

# %%
model = LogisticRegression()

model.fit(x_train, x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 3
#       1 model = LogisticRegression()
# ----> 3 model.fit(x_train, x_test)
#
# File c:\Code\6th-Sem-OU\6th-sem\lib\site-packages\sklearn\base.py:1351, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1344     estimator._validate_params()
#    1346 with config_context(
#    1347     skip_parameter_validation=(
#    1348         prefer_skip_nested_validation or global_skip_validation
#    1349     )
#    1350 ):
# -> 1351     return fit_method(estimator, *args, **kwargs)
#
# File c:\Code\6th-Sem-OU\6th-sem\lib\site-packages\sklearn\linear_model\_logistic.py:1201, in LogisticRegression.fit(self, X, y, sample_weight)
#    1198 else:
#    1199     _dtype = [np.float64, np.float32]
# -> 1201 X, y = self._validate_data(
#    1202     X,
#    1203     y,
#    1204     accept_sparse="csr",
#    1205     dtype=_dtype,
#    1206     order="C",
#    1207     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1208 )
#    1209 check_classification_targets(y)
#    1210 self.classes_ = np.unique(y)
#
# File c:\Code\6th-Sem-OU\6th-sem\lib\site-packages\sklearn\base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File c:\Code\6th-Sem-OU\6th-sem\lib\site-packages\sklearn\utils\validation.py:1208, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1188     raise ValueError(
#    1189         f"{estimator_name} requires y to be passed, but the target y is None"
#    1190     )
#    1192 X = check_array(
#    1193     X,
#    1194     accept_sparse=accept_sparse,
#    (...)
#    1205     input_name="X",
#    1206 )
# -> 1208 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1210 check_consistent_length(X, y)
#    1212 return X, y
#
# File c:\Code\6th-Sem-OU\6th-sem\lib\site-packages\sklearn\utils\validation.py:1229, in _check_y(y, multi_output, y_numeric, estimator)
#    1227 else:
#    1228     estimator_name = _check_estimator_name(estimator)
# -> 1229     y = column_or_1d(y, warn=True)
#    1230     _assert_all_finite(y, input_name="y", estimator_name=estimator_name)
#    1231     _ensure_no_complex_data(y)
#
# File c:\Code\6th-Sem-OU\6th-sem\lib\site-packages\sklearn\utils\validation.py:1296, in column_or_1d(y, dtype, warn)
#    1285         warnings.warn(
#    1286             (
#    1287                 "A column-vector y was passed when a 1d array was"
#    (...)
#    1292             stacklevel=2,
#    1293         )
#    1294     return _asarray_with_order(xp.reshape(y, (-1,)), order="C", xp=xp)
# -> 1296 raise ValueError(
#    1297     "y should be a 1d array, got an array of shape {} instead.".format(shape)
#    1298 )
#
# ValueError: y should be a 1d array, got an array of shape (179, 6) instead.

# %%
model.score(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 model.score(x_train, y_train)
#
# File c:\Code\6th-Sem-OU\6th-sem\lib\site-packages\sklearn\base.py:764, in ClassifierMixin.score(self, X, y, sample_weight)
#     739 """
#     740 Return the mean accuracy on the given test data and labels.
#     741
#    (...)
#     760     Mean accuracy of ``self.predict(X)`` w.r.t. `y`.
#     761 """
#     762 from .metrics import accuracy_score
# --> 764 return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#
# File c:\Code\6th-Sem-OU\6th-sem\lib\site-packages\sklearn\linear_model\_base.py:351, in LinearClassifierMixin.predict(self, X)
#     337 """
#     338 Predict class labels for samples in X.
#     339
#    (...)
#     348     Vector containing the class labels for each sample.
#     349 """
#     350 xp, _ = get_namespace(X)
# --> 351 scores = self.decision_function(X)
#     352 if len(scores.shape) == 1:
#     353     indices = xp.astype(scores > 0, int)
#
# File c:\Code\6th-Sem-OU\6th-sem\lib\site-packages\sklearn\linear_model\_base.py:333, in LinearClassifierMixin.decision_function(self, X)
#     330 xp, _ = get_namespace(X)
#     332 X = self._validate_data(X, accept_sparse="csr", reset=False)
# --> 333 scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     334 return xp.reshape(scores, (-1,)) if scores.shape[1] == 1 else scores
#
# AttributeError: 'LogisticRegression' object has no attribute 'coef_'
